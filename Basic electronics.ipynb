# %% [markdown]
# As any sort of engineer you should have some knowledge of electronics, and by learning a couple of core concepts you can get a reasonable handle on how to calculate or construct various circuits (or at least to know what the bits are when you're ripping them apart or hacking and debugging them). So here's a _very_ brief reminder of basic circuti methods, calculations and components.

# %% [markdown]
# # Ohm's Law: V = IR

# %% [markdown]
# This is the electronics equivalent of saying '_the harder you push something the faster it goes_'. The voltage (_V_) is the electronic potential of the circuit (an electronic analogue of the height something is at relative to a graviational field) which provides the electronic _push_ that moves electrons around the circuit. The current (_I_) is how quickly charges move through the circuit as a consequence of the push (literally $I = \frac{dQ}{dt}$, the rate of change of the charges (_Q_) in the circuit). Finally the resisitance (_R_) is how much the circuit (or parts of the circuit) resist the flow of current. Going back to our height analogy, imagine taking an object to the top of a building and dropping it off. The height of the building is the potential in this system (and note that it takes work to carry the object up there because you're moving it _against_ the direction of the gravitational field). How fast does the thing fall? We don't know. The rate of fall here is our analogue of current and our resistance analogue is air resistance. So something like a feather will drop slowly (low current) because it has high resistance even if it's exposed to a high voltage. Conversly, a bowling ball will have a much lower resistance and so will fall faster. As with all analogies though, this one isn't perfect (that's why many people prefer to talk about analogies with flowing water instead which is a far superior analogy to mine).

# %%
from IPython.display import Image
Image('https://raw.githubusercontent.com/kaiwhata/Educational_resources/master/ohms_law_circuit.png', width=300)

# %% [markdown]
# here's an example circuit for Ohm's law with the ammeter measuring current. Note how any one characteristic (_V, I_ or _R_) can be calculated if the other two are known

# %% [markdown]
# # Voltage Dividers

# %% [markdown]
# So here's and example of why you might be intersted in Ohm's law a for circuits. You may be aware that many microcontrollers operate using binary logic and that they use standard voltages of either 5 (most arduinos) or 3.3 Volts (the Rasberry Pi). Many sensors operate on the same voltages but what happens if you have a sensor with a 5V output but you want to connect it to a 3.3V system? Well if you connect it directly the the increased voltage may destroy your microcontroller (unlikely though). But we can use Ohm's law and a couple of resistors to divide the voltage across a few resistors and thus limit the voltage across our microcontroller to a nice, safe 3.3V.

# %%
Image('https://raw.githubusercontent.com/kaiwhata/Educational_resources/master/voltage_divider_circuit.png', width=300)

# %% [markdown]
# In the above example hopefully it's clear that the ratio of resistances between the two resistors determines the voltage at the  middle line out. The total resistance ($R_T$) for resistors in series like this just adds together. You may have seen it expressed as:
#
# $R_T = R_1 + R_2$
# or in this case
# $R_T = 34 + 66 = 100 \Omega $
# and hence the total current through the circuit is
# $I = \frac{V}{R} = \frac{5}{100} = 0.05 A$

# %% [markdown]
# # Work: W=F.d

# %% [markdown]
# Just quickly we need to take a look at a concept i mentioned in the first paragraph - Work. Physically work is _required_ when you want to move something some displacement (_d_) **against** a potential. Think about it - if a ball box is sitting on the floor, you wouldn't expect it to jump up onto a table unless someone or something expended energy (i.e. _work_) to lift it up and place it there. It's exactly the same in an electrical system - we wouldn't expect a charged object to move 'up' and electric potential unless something was doing work on it. Furthermore we can figure out exactly how much work is required to move it by multiplying the force required to move it by the displacement it is moved. Why do I keep saying _displacement_ and not _distance_? Because the direction of the movement is **really** important. Looking back to our box on the floor, it takes almost no work to push it across the floor (apart from what is needed to combat friction) because we're moving it perpendicular to the potential field. But if we move it parallel to the field (i.e. up onto the desk) then we do have to do work. The _displacement_ I keep mentioning is the distance parallel to the potential direction it is being moved. Finally th amount of work is measued in Joules, the unity of energy because that is exactly what is used up when we do work.
#
# Warning: There is one fatal flaw in this analogy - gravity only attracts so gravitational potentials only accelerate things in one direction. For electronics we have two possible charges (positive or negative) which react to an electrical potential in exactly opposite ways. Imagine if we discovered something that could do that with gravitational fields! Why might we not have discovered it yet if it does, in fact, exist?

# %% [markdown]
# # Power: P = VI

# %% [markdown]
# Power is the rate of use of energy (or energy transfer), and hence its units are Watts (or equivalently Joules per Second). We can calulate the power used by (or emitted by) any component of a circuit using the relationship $P=VI$ or alternatively formulated as $P = \frac{V^2}{R} = I^2 R$. Immediately this should show why high voltage (and not high current) is used to transfer power long distances - for instance think about a km long wire with a resistance of 100 $\Omega$s. How much power is lost from it if we set up a potential difference of 10V across the cable? How much power is lost of we push 10A of current down the cable?

# %% [markdown]
# You can also connect Power to Work. Doing work requires energy, and the rate of change of that energy is the power. So a large amount of work for a long time requires a large amount of power. You can get away with much smaller amounts of power if you only use it for short periods of time. As an example try and drive several servos through an arduino at once. To protect their electronics, many microcontrollers have current limitations through them (usually 500mA or there abouts) which limits the amount of power they can transfer from one place to another. Try and use to much power at once and your arduino will crash. But if you only drive one servo at a time (and you can swap between each several times a second) and you can get around your power limitations by making use of clever timing.

# %% [markdown]
# # Kirchoff's Voltage Law: $\Sigma V = 0$

# %% [markdown]
# In the voltage divider example above we actually made use of this law already. The law states that the sum of voltages around a closed loop in a circuit must equal 0. This simple law will be of great help in solving problems ontaining complex circuits because it allows you to focus on only one loop at a time. In the voltage divider example we would write that
# $V_{battery} - V_{R1} - V_{R2} = 5 - 1.7 - 3.3 = 0$
# However if we **didnt** know one of those values, we could figure it out from the equation above, rearranging and solving for the unknown. Note that the voltage adds to the total voltage (so multiple batteries in series give you more volts) whereas resistive elements like resistors and some others sumtract from the total number of voltages. Actually this depends on the direction of the current through the circuit.
# Why does this work? Well think about what would happen to our circuit if the voltages didn't add to 0 around the close loop. That would mean that after completing the loop, the circuit would still have a little energy left which it would deposit into the battery, thus increasing it's voltage which would increase the amount left over after the loop was complete which would increase the battery voltage which would increase the amount left over after the loop....and so on. This would be tantamount to getting energy from nowhere!

# %% [markdown]
# # Kirchoff's Current Law: $ I_{in} = I_{out}$

# %% [markdown]
# Similar to the voltage law - the current law allows you to write simlpe expressions describing particular parts of the circuit; in this case specifically junctions. Simply put - the totall current into a junction in a circuit must equal the total current out of a junction.
# Think about why: what would happen if more came into the junction then left it? Current is just the flow of charge so that would mean that charge would build up at the junction. But like charges repel, so the more charge built up the harder it would be for more charge to accumulate the the easier it would be for existing charges to leave. So this 'law' is actually just a statement of the electrical equilibrium of a circuit: _i.e. if charges arre free to move then they can't build up anywhere in the circuit because they all repel each other_. In practice using it tends to look something like this:

# %% [markdown]
# #

# %% [markdown]
# # Capacitors

# %% [markdown]
# $ I = I_0 e^{\frac{-t}{\tau}}$

# %%
def I(t, I0, tau):
    return (I0*exp(-1*t/tau))

# %% [markdown]
# $\tau = \frac{R}{C}$

# %% [markdown]
# $C = \frac{\varepsilon A}{d}$

# %%
from numpy import linspace

# %%
t = linspace(0,100, 100)

# %%
plot(t, [I(i, 1.0, 10.0/0.02) for i in t], 'b.-', label='$R = 10 \Omega,$ $C = 2 mF$')
plot(t, [I(i, 1.0, 1.0/0.02) for i in t], 'k.-', label='$R = 1 \Omega,$ $C = 2 mF$')
plot(t, [I(i, 1.0, 1.0/0.05) for i in t], 'r.-', label='$R = 1 \Omega,$ $C = 5 mF$')
ylim(0,1.1)
xlim(0,110 )
xlabel('Time / s')
ylabel('Current / %')
legend(loc='best')

# %% [markdown]
# # Useful notes

# %% [markdown]
# There is a LaTeX package for drawing electronic circuits called _Circuitikz_. There's a nice tutorial for getting you started with it [here](https://www.sharelatex.com/blog/2013/09/02/tikz-series-pt4.html) and I've done all the circuit graphics in this document using it to give you an example of what can be easily be drawn with it.
